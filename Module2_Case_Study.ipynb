# %%
# Name: Manuel Verdin
# File Name: Module2_Case_Study.ipynb
# Description: This program accepts student names and GPAs
# and determines whether students qualify for the Dean's List or the Honor Roll

# %%
last_name = input("Enter student's last name (ZZZ to quit): ")

while last_name != "ZZZ":

    first_name = input("Enter student's first name: ")

    gpa = float(input("Enter student's GPA: "))

    if gpa >= 3.5:
        print(first_name, last_name, "has made the Dean's List.")

    elif gpa >= 3.25:
        print(first_name, last_name, "has made the Honor Roll.")

    else:
        print(first_name, last_name, "does not qualify for either list.")

    print()

    last_name = input("Enter student's last name (ZZZ to quit): ")

print("Program ended.")
# Out:
# Enter student's last name (ZZZ to quit):  Royston
# Enter student's first name:  Matthew
# Enter student's GPA:  3.8
# Matthew Royston has made the Dean's List.
# Enter student's last name (ZZZ to quit):  Dougherty
# Enter student's first name:  Ally
# Enter student's GPA:  3.4
# Ally Dougherty has made the Honor Roll.
# Enter student's last name (ZZZ to quit):  Cortrecht
# Enter student's first name:  Kaleb
# Enter student's GPA:  3.2
# Kaleb Cortrecht does not qualify for either list.
# Enter student's last name (ZZZ to quit):  Clear
# Enter student's first name:  Andrew
# Enter student's GPA:  4.0
# Andrew Clear has made the Dean's List.
# Enter student's last name (ZZZ to quit):  Gosler
# Enter student's first name:  Thomas
# Enter student's GPA:  3.3
# Thomas Gosler has made the Honor Roll.
# Enter student's last name (ZZZ to quit):  ZZZ
# Program ended.

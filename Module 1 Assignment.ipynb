# %%
60 * 60
# Out:
# 3600

# %%
seconds_per_hour = 60 * 60
seconds_per_hour
# Out:
# 3600

# %%
seconds_per_hour * 24
# Out:
# 86400

# %%
seconds_per_day = seconds_per_hour * 24
seconds_per_day
# Out:
# 86400

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %% [markdown]
# The result is 24.0 because floating-point division returns a decimal value.

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# Yes this answer agrees with the previous question. The only difference is that integer division returns 24 instead of 24.0
